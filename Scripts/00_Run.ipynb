# %%
# Run the other files in the current directory in order
# %run 01_data_cleaning.ipynb
# %run 02_eda.ipynb
# %run 03_regression.ipynb
# Out:
# [NbConvertApp] Converting notebook 01_data_cleaning.ipynb to notebook
# C:\Users\ceero\anaconda3\envs\myenv\Lib\site-packages\zmq\_future.py:679: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# [NbConvertApp] Writing 21592 bytes to data_cleaning_executed.ipynb
# ^C
