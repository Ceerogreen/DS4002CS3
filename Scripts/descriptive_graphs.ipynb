# %%
# Import data science libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
# Read in combined dataset
data = pd.read_csv('../Data/combined_admissions_characteristics.csv')
# Out:
# C:\Users\ceero\AppData\Local\Temp\ipykernel_18092\1521450588.py:2: DtypeWarning: Columns (56,58,72,74,80,82,84,86,88,90,92,94,96,98,100,102,104,106,108,121,147,184,185,198) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../Data/combined_admissions_characteristics.csv')
